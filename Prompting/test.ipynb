# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in /Users/kumar/miniconda3/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (2.2.2)
# Collecting pydantic (from -r requirements.txt (line 2))
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting langchain (from -r requirements.txt (line 3))
#   Using cached langchain-1.2.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting langchain-core (from -r requirements.txt (line 4))
#   Using cached langchain_core-1.2.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting langchain-community (from -r requirements.txt (line 5))
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-ollama (from -r requirements.txt (line 6))
#   Using cached langchain_ollama-1.0.1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: scikit-learn in /Users/kumar/miniconda3/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (1.7.1)
# Collecting vllm (from -r requirements.txt (line 8))
#   Using cached vllm-0.12.0.tar.gz (17.6 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch in /Users/kumar/miniconda3/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (2.9.1)
# Collecting transformers (from -r requirements.txt (line 10))
#   Using cached transformers-4.57.3-py3-none-any.whl.metadata (43 kB)
# Collecting sentencepiece (from -r requirements.txt (line 11))
#   Using cached sentencepiece-0.2.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.26.0 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 1)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 1)) (2023.3)
# Collecting annotated-types>=0.6.0 (from pydantic->-r requirements.txt (line 2))
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic->-r requirements.txt (line 2))
#   Using cached pydantic_core-2.41.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from pydantic->-r requirements.txt (line 2)) (4.15.0)
# Collecting typing-inspection>=0.4.2 (from pydantic->-r requirements.txt (line 2))
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting langgraph<1.1.0,>=1.0.2 (from langchain->-r requirements.txt (line 3))
#   Using cached langgraph-1.0.5-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from langchain-core->-r requirements.txt (line 4)) (1.33)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core->-r requirements.txt (line 4))
#   Using cached langsmith-0.5.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from langchain-core->-r requirements.txt (line 4)) (23.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from langchain-core->-r requirements.txt (line 4)) (6.0.2)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core->-r requirements.txt (line 4))
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core->-r requirements.txt (line 4))
#   Using cached uuid_utils-0.12.0-cp39-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (1.1 kB)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain-community->-r requirements.txt (line 5))
#   Using cached langchain_classic-1.0.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from langchain-community->-r requirements.txt (line 5)) (2.0.44)
# Collecting requests<3.0.0,>=2.32.5 (from langchain-community->-r requirements.txt (line 5))
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community->-r requirements.txt (line 5))
#   Using cached aiohttp-3.13.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community->-r requirements.txt (line 5))
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community->-r requirements.txt (line 5))
#   Using cached pydantic_settings-2.12.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community->-r requirements.txt (line 5))
#   Using cached httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting ollama<1.0.0,>=0.6.0 (from langchain-ollama->-r requirements.txt (line 6))
#   Using cached ollama-0.6.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: scipy>=1.8.0 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from scikit-learn->-r requirements.txt (line 7)) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from scikit-learn->-r requirements.txt (line 7)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from scikit-learn->-r requirements.txt (line 7)) (3.5.0)
# Collecting regex (from vllm->-r requirements.txt (line 8))
#   Using cached regex-2025.11.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting cachetools (from vllm->-r requirements.txt (line 8))
#   Using cached cachetools-6.2.4-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: psutil in /Users/kumar/miniconda3/lib/python3.12/site-packages (from vllm->-r requirements.txt (line 8)) (5.9.0)
# Requirement already satisfied: tqdm in /Users/kumar/miniconda3/lib/python3.12/site-packages (from vllm->-r requirements.txt (line 8)) (4.65.0)
# Collecting blake3 (from vllm->-r requirements.txt (line 8))
#   Using cached blake3-1.0.8-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.6 kB)
# Collecting py-cpuinfo (from vllm->-r requirements.txt (line 8))
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting tokenizers>=0.21.1 (from vllm->-r requirements.txt (line 8))
#   Using cached tokenizers-0.22.1-cp39-abi3-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: protobuf in /Users/kumar/miniconda3/lib/python3.12/site-packages (from vllm->-r requirements.txt (line 8)) (6.33.0)
# Collecting fastapi>=0.115.0 (from fastapi[standard]>=0.115.0->vllm->-r requirements.txt (line 8))
#   Using cached fastapi-0.125.0-py3-none-any.whl.metadata (30 kB)
# Collecting openai>=1.99.1 (from vllm->-r requirements.txt (line 8))
#   Using cached openai-2.13.0-py3-none-any.whl.metadata (29 kB)
# Collecting prometheus_client>=0.18.0 (from vllm->-r requirements.txt (line 8))
#   Using cached prometheus_client-0.23.1-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: pillow in /Users/kumar/miniconda3/lib/python3.12/site-packages (from vllm->-r requirements.txt (line 8)) (10.4.0)
# Collecting prometheus-fastapi-instrumentator>=7.0.0 (from vllm->-r requirements.txt (line 8))
#   Using cached prometheus_fastapi_instrumentator-7.1.0-py3-none-any.whl.metadata (13 kB)
# Collecting tiktoken>=0.6.0 (from vllm->-r requirements.txt (line 8))
#   Using cached tiktoken-0.12.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting lm-format-enforcer==0.11.3 (from vllm->-r requirements.txt (line 8))
#   Using cached lm_format_enforcer-0.11.3-py3-none-any.whl.metadata (17 kB)
# Collecting llguidance<1.4.0,>=1.3.0 (from vllm->-r requirements.txt (line 8))
#   Using cached llguidance-1.3.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (10 kB)
# Collecting outlines_core==0.2.11 (from vllm->-r requirements.txt (line 8))
#   Using cached outlines_core-0.2.11-cp312-cp312-macosx_15_0_arm64.whl.metadata (5.8 kB)
# Collecting diskcache==5.6.3 (from vllm->-r requirements.txt (line 8))
#   Using cached diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Collecting lark==1.2.2 (from vllm->-r requirements.txt (line 8))
#   Using cached lark-1.2.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting xgrammar==0.1.27 (from vllm->-r requirements.txt (line 8))
#   Using cached xgrammar-0.1.27-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: filelock>=3.16.1 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from vllm->-r requirements.txt (line 8)) (3.20.0)
# Collecting partial-json-parser (from vllm->-r requirements.txt (line 8))
#   Using cached partial_json_parser-0.2.1.1.post7-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: pyzmq>=25.0.0 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from vllm->-r requirements.txt (line 8)) (25.1.2)
# Collecting msgspec (from vllm->-r requirements.txt (line 8))
#   Using cached msgspec-0.20.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting gguf>=0.17.0 (from vllm->-r requirements.txt (line 8))
#   Using cached gguf-0.17.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting mistral_common>=1.8.5 (from mistral_common[image]>=1.8.5->vllm->-r requirements.txt (line 8))
#   Using cached mistral_common-1.8.6-py3-none-any.whl.metadata (5.3 kB)
# Collecting opencv-python-headless>=4.11.0 (from vllm->-r requirements.txt (line 8))
#   Using cached opencv_python_headless-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl.metadata (19 kB)
# Requirement already satisfied: six>=1.16.0 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from vllm->-r requirements.txt (line 8)) (1.16.0)
# Collecting setuptools<81.0.0,>=77.0.3 (from vllm->-r requirements.txt (line 8))
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting einops (from vllm->-r requirements.txt (line 8))
#   Using cached einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting compressed-tensors==0.12.2 (from vllm->-r requirements.txt (line 8))
#   Using cached compressed_tensors-0.12.2-py3-none-any.whl.metadata (7.0 kB)
# Collecting depyf==0.20.0 (from vllm->-r requirements.txt (line 8))
#   Using cached depyf-0.20.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting cloudpickle (from vllm->-r requirements.txt (line 8))
#   Using cached cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting watchfiles (from vllm->-r requirements.txt (line 8))
#   Using cached watchfiles-1.1.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Requirement already satisfied: python-json-logger in /Users/kumar/miniconda3/lib/python3.12/site-packages (from vllm->-r requirements.txt (line 8)) (2.0.7)
# Collecting ninja (from vllm->-r requirements.txt (line 8))
#   Using cached ninja-1.13.0-py3-none-macosx_10_9_universal2.whl.metadata (5.1 kB)
# Collecting pybase64 (from vllm->-r requirements.txt (line 8))
#   Using cached pybase64-1.4.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.7 kB)
# Collecting cbor2 (from vllm->-r requirements.txt (line 8))
#   Using cached cbor2-5.7.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.4 kB)
# Collecting setproctitle (from vllm->-r requirements.txt (line 8))
#   Using cached setproctitle-1.3.7-cp312-cp312-macosx_11_0_arm64.whl.metadata (10 kB)
# Collecting openai-harmony>=0.0.3 (from vllm->-r requirements.txt (line 8))
#   Using cached openai_harmony-0.0.8-cp38-abi3-macosx_11_0_arm64.whl.metadata (8.0 kB)
# Collecting anthropic==0.71.0 (from vllm->-r requirements.txt (line 8))
#   Using cached anthropic-0.71.0-py3-none-any.whl.metadata (28 kB)
# Collecting model-hosting-container-standards<1.0.0,>=0.1.9 (from vllm->-r requirements.txt (line 8))
#   Using cached model_hosting_container_standards-0.1.12-py3-none-any.whl.metadata (24 kB)
# Collecting numba==0.61.2 (from vllm->-r requirements.txt (line 8))
#   Using cached numba-0.61.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.8 kB)
# Collecting torchaudio (from vllm->-r requirements.txt (line 8))
#   Using cached torchaudio-2.9.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.9 kB)
# Requirement already satisfied: torchvision in /Users/kumar/miniconda3/lib/python3.12/site-packages (from vllm->-r requirements.txt (line 8)) (0.24.1)
# Requirement already satisfied: sympy>=1.13.3 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from torch->-r requirements.txt (line 9)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from torch->-r requirements.txt (line 9)) (3.5)
# Requirement already satisfied: jinja2 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from torch->-r requirements.txt (line 9)) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from torch->-r requirements.txt (line 9)) (2025.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from anthropic==0.71.0->vllm->-r requirements.txt (line 8)) (4.6.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from anthropic==0.71.0->vllm->-r requirements.txt (line 8)) (1.8.0)
# Collecting docstring-parser<1,>=0.15 (from anthropic==0.71.0->vllm->-r requirements.txt (line 8))
#   Using cached docstring_parser-0.17.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from anthropic==0.71.0->vllm->-r requirements.txt (line 8)) (0.27.0)
# Collecting jiter<1,>=0.4.0 (from anthropic==0.71.0->vllm->-r requirements.txt (line 8))
#   Using cached jiter-0.12.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Requirement already satisfied: sniffio in /Users/kumar/miniconda3/lib/python3.12/site-packages (from anthropic==0.71.0->vllm->-r requirements.txt (line 8)) (1.3.0)
# Collecting loguru (from compressed-tensors==0.12.2->vllm->-r requirements.txt (line 8))
#   Using cached loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Collecting astor (from depyf==0.20.0->vllm->-r requirements.txt (line 8))
#   Using cached astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting dill (from depyf==0.20.0->vllm->-r requirements.txt (line 8))
#   Using cached dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting interegular>=0.3.2 (from lm-format-enforcer==0.11.3->vllm->-r requirements.txt (line 8))
#   Using cached interegular-0.3.3-py37-none-any.whl.metadata (3.0 kB)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba==0.61.2->vllm->-r requirements.txt (line 8))
#   Using cached llvmlite-0.44.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Collecting mlx-lm (from xgrammar==0.1.27->vllm->-r requirements.txt (line 8))
#   Using cached mlx_lm-0.29.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting huggingface-hub<1.0,>=0.34.0 (from transformers->-r requirements.txt (line 10))
#   Using cached huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# Collecting safetensors>=0.4.3 (from transformers->-r requirements.txt (line 10))
#   Using cached safetensors-0.7.0-cp38-abi3-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 5))
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 5))
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 5)) (24.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 5))
#   Using cached frozenlist-1.8.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 5))
#   Using cached multidict-6.7.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 5))
#   Using cached propcache-0.4.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 5))
#   Using cached yarl-1.22.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (75 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community->-r requirements.txt (line 5))
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community->-r requirements.txt (line 5))
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting starlette<0.51.0,>=0.40.0 (from fastapi>=0.115.0->fastapi[standard]>=0.115.0->vllm->-r requirements.txt (line 8))
#   Using cached starlette-0.50.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi>=0.115.0->fastapi[standard]>=0.115.0->vllm->-r requirements.txt (line 8))
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting fastapi-cli>=0.0.8 (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm->-r requirements.txt (line 8))
#   Using cached fastapi_cli-0.0.16-py3-none-any.whl.metadata (6.4 kB)
# Collecting jinja2 (from torch->-r requirements.txt (line 9))
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting python-multipart>=0.0.18 (from fastapi[standard]>=0.115.0->vllm->-r requirements.txt (line 8))
#   Using cached python_multipart-0.0.21-py3-none-any.whl.metadata (1.8 kB)
# Collecting email-validator>=2.0.0 (from fastapi[standard]>=0.115.0->vllm->-r requirements.txt (line 8))
#   Using cached email_validator-2.3.0-py3-none-any.whl.metadata (26 kB)
# Collecting uvicorn>=0.12.0 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm->-r requirements.txt (line 8))
#   Using cached uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface-hub<1.0,>=0.34.0->transformers->-r requirements.txt (line 10))
#   Using cached hf_xet-1.2.0-cp37-abi3-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from jinja2->torch->-r requirements.txt (line 9)) (2.1.3)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core->-r requirements.txt (line 4)) (2.1)
# Collecting langchain-text-splitters<2.0.0,>=1.0.0 (from langchain-classic<2.0.0,>=1.0.0->langchain-community->-r requirements.txt (line 5))
#   Using cached langchain_text_splitters-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting langgraph-checkpoint<4.0.0,>=2.1.0 (from langgraph<1.1.0,>=1.0.2->langchain->-r requirements.txt (line 3))
#   Using cached langgraph_checkpoint-3.0.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.2 (from langgraph<1.1.0,>=1.0.2->langchain->-r requirements.txt (line 3))
#   Using cached langgraph_prebuilt-1.0.5-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph<1.1.0,>=1.0.2->langchain->-r requirements.txt (line 3))
#   Using cached langgraph_sdk-0.3.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.1.0,>=1.0.2->langchain->-r requirements.txt (line 3))
#   Using cached xxhash-3.6.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting orjson>=3.9.14 (from langsmith<1.0.0,>=0.3.45->langchain-core->-r requirements.txt (line 4))
#   Using cached orjson-3.11.5-cp312-cp312-macosx_15_0_arm64.whl.metadata (41 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core->-r requirements.txt (line 4))
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core->-r requirements.txt (line 4))
#   Using cached zstandard-0.25.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.3 kB)
# Requirement already satisfied: jsonschema>=4.21.1 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from mistral_common>=1.8.5->mistral_common[image]>=1.8.5->vllm->-r requirements.txt (line 8)) (4.23.0)
# Collecting pydantic-extra-types>=2.10.5 (from pydantic-extra-types[pycountry]>=2.10.5->mistral_common>=1.8.5->mistral_common[image]>=1.8.5->vllm->-r requirements.txt (line 8))
#   Using cached pydantic_extra_types-2.10.6-py3-none-any.whl.metadata (4.0 kB)
# Collecting jmespath (from model-hosting-container-standards<1.0.0,>=0.1.9->vllm->-r requirements.txt (line 8))
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting supervisor>=4.2.0 (from model-hosting-container-standards<1.0.0,>=0.1.9->vllm->-r requirements.txt (line 8))
#   Using cached supervisor-4.3.0-py2.py3-none-any.whl.metadata (87 kB)
# Collecting numpy>=1.26.0 (from pandas->-r requirements.txt (line 1))
#   Using cached numpy-2.2.6-cp312-cp312-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain-community->-r requirements.txt (line 5))
#   Using cached python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community->-r requirements.txt (line 5)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community->-r requirements.txt (line 5)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community->-r requirements.txt (line 5)) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community->-r requirements.txt (line 5)) (2025.8.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 9)) (1.3.0)
# Collecting dnspython>=2.0.0 (from email-validator>=2.0.0->fastapi[standard]>=0.115.0->vllm->-r requirements.txt (line 8))
#   Using cached dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting typer>=0.15.1 (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm->-r requirements.txt (line 8))
#   Using cached typer-0.20.0-py3-none-any.whl.metadata (16 kB)
# Collecting rich-toolkit>=0.14.8 (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm->-r requirements.txt (line 8))
#   Using cached rich_toolkit-0.17.1-py3-none-any.whl.metadata (1.0 kB)
# Collecting fastapi-cloud-cli>=0.1.1 (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm->-r requirements.txt (line 8))
#   Using cached fastapi_cloud_cli-0.7.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: httpcore==1.* in /Users/kumar/miniconda3/lib/python3.12/site-packages (from httpx<1,>=0.25.0->anthropic==0.71.0->vllm->-r requirements.txt (line 8)) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic==0.71.0->vllm->-r requirements.txt (line 8)) (0.14.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from jsonschema>=4.21.1->mistral_common>=1.8.5->mistral_common[image]>=1.8.5->vllm->-r requirements.txt (line 8)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from jsonschema>=4.21.1->mistral_common>=1.8.5->mistral_common[image]>=1.8.5->vllm->-r requirements.txt (line 8)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from jsonschema>=4.21.1->mistral_common>=1.8.5->mistral_common[image]>=1.8.5->vllm->-r requirements.txt (line 8)) (0.10.6)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain->-r requirements.txt (line 3))
#   Using cached ormsgpack-1.12.1-cp312-cp312-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (3.2 kB)
# Collecting pycountry>=23 (from pydantic-extra-types[pycountry]>=2.10.5->mistral_common>=1.8.5->mistral_common[image]>=1.8.5->vllm->-r requirements.txt (line 8))
#   Using cached pycountry-24.6.1-py3-none-any.whl.metadata (12 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community->-r requirements.txt (line 5))
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: click>=7.0 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from uvicorn>=0.12.0->uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm->-r requirements.txt (line 8)) (8.3.1)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm->-r requirements.txt (line 8))
#   Using cached httptools-0.7.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.5 kB)
# Collecting uvloop>=0.15.1 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm->-r requirements.txt (line 8))
#   Using cached uvloop-0.22.1-cp312-cp312-macosx_10_13_universal2.whl.metadata (4.9 kB)
# Requirement already satisfied: websockets>=10.4 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm->-r requirements.txt (line 8)) (15.0.1)
# Collecting mlx>=0.29.2 (from mlx-lm->xgrammar==0.1.27->vllm->-r requirements.txt (line 8))
#   Using cached mlx-0.30.1-cp312-cp312-macosx_26_0_arm64.whl.metadata (5.9 kB)
# Collecting rignore>=0.5.1 (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm->-r requirements.txt (line 8))
#   Using cached rignore-0.7.6-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Collecting sentry-sdk>=2.20.0 (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm->-r requirements.txt (line 8))
#   Using cached sentry_sdk-2.48.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting fastar>=0.8.0 (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm->-r requirements.txt (line 8))
#   Using cached fastar-0.8.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Collecting mlx-metal==0.30.1 (from mlx>=0.29.2->mlx-lm->xgrammar==0.1.27->vllm->-r requirements.txt (line 8))
#   Using cached mlx_metal-0.30.1-py3-none-macosx_26_0_arm64.whl.metadata (5.1 kB)
# Requirement already satisfied: rich>=13.7.1 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm->-r requirements.txt (line 8)) (14.2.0)
# Collecting shellingham>=1.3.0 (from typer>=0.15.1->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm->-r requirements.txt (line 8))
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm->-r requirements.txt (line 8)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm->-r requirements.txt (line 8)) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm->-r requirements.txt (line 8)) (0.1.2)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp312-cp312-macosx_11_0_arm64.whl (1.9 MB)
# Using cached langchain-1.2.0-py3-none-any.whl (102 kB)
# Using cached langchain_core-1.2.2-py3-none-any.whl (476 kB)
# Using cached langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
# Using cached langchain_ollama-1.0.1-py3-none-any.whl (29 kB)
# Using cached anthropic-0.71.0-py3-none-any.whl (355 kB)
# Using cached compressed_tensors-0.12.2-py3-none-any.whl (183 kB)
# Using cached depyf-0.20.0-py3-none-any.whl (39 kB)
# Using cached diskcache-5.6.3-py3-none-any.whl (45 kB)
# Using cached lark-1.2.2-py3-none-any.whl (111 kB)
# Using cached lm_format_enforcer-0.11.3-py3-none-any.whl (45 kB)
# Using cached numba-0.61.2-cp312-cp312-macosx_11_0_arm64.whl (2.8 MB)
# Using cached outlines_core-0.2.11-cp312-cp312-macosx_15_0_arm64.whl (2.0 MB)
# Using cached xgrammar-0.1.27-cp312-cp312-macosx_11_0_arm64.whl (636 kB)
# Using cached transformers-4.57.3-py3-none-any.whl (12.0 MB)
# Using cached sentencepiece-0.2.1-cp312-cp312-macosx_11_0_arm64.whl (1.3 MB)
# Using cached aiohttp-3.13.2-cp312-cp312-macosx_11_0_arm64.whl (491 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached fastapi-0.125.0-py3-none-any.whl (112 kB)
# Using cached gguf-0.17.1-py3-none-any.whl (96 kB)
# Using cached httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Using cached huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached langchain_classic-1.0.0-py3-none-any.whl (1.0 MB)
# Using cached langgraph-1.0.5-py3-none-any.whl (157 kB)
# Using cached langsmith-0.5.0-py3-none-any.whl (273 kB)
# Using cached llguidance-1.3.0-cp39-abi3-macosx_11_0_arm64.whl (3.1 MB)
# Using cached mistral_common-1.8.6-py3-none-any.whl (6.5 MB)
# Using cached model_hosting_container_standards-0.1.12-py3-none-any.whl (105 kB)
# Using cached ollama-0.6.1-py3-none-any.whl (14 kB)
# Using cached openai-2.13.0-py3-none-any.whl (1.1 MB)
# Using cached openai_harmony-0.0.8-cp38-abi3-macosx_11_0_arm64.whl (2.6 MB)
# Using cached opencv_python_headless-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl (37.9 MB)
# Using cached numpy-2.2.6-cp312-cp312-macosx_14_0_arm64.whl (5.1 MB)
# Using cached prometheus_client-0.23.1-py3-none-any.whl (61 kB)
# Using cached prometheus_fastapi_instrumentator-7.1.0-py3-none-any.whl (19 kB)
# Using cached pydantic_settings-2.12.0-py3-none-any.whl (51 kB)
# Using cached regex-2025.11.3-cp312-cp312-macosx_11_0_arm64.whl (288 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached safetensors-0.7.0-cp38-abi3-macosx_11_0_arm64.whl (447 kB)
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached tiktoken-0.12.0-cp312-cp312-macosx_11_0_arm64.whl (994 kB)
# Using cached tokenizers-0.22.1-cp39-abi3-macosx_11_0_arm64.whl (2.9 MB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached uuid_utils-0.12.0-cp39-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (603 kB)
# Using cached blake3-1.0.8-cp312-cp312-macosx_11_0_arm64.whl (325 kB)
# Using cached cachetools-6.2.4-py3-none-any.whl (11 kB)
# Using cached cbor2-5.7.1-cp312-cp312-macosx_11_0_arm64.whl (68 kB)
# Using cached cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Using cached einops-0.8.1-py3-none-any.whl (64 kB)
# Using cached msgspec-0.20.0-cp312-cp312-macosx_11_0_arm64.whl (188 kB)
# Using cached ninja-1.13.0-py3-none-macosx_10_9_universal2.whl (310 kB)
# Using cached partial_json_parser-0.2.1.1.post7-py3-none-any.whl (10 kB)
# Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Using cached pybase64-1.4.3-cp312-cp312-macosx_11_0_arm64.whl (31 kB)
# Using cached setproctitle-1.3.7-cp312-cp312-macosx_11_0_arm64.whl (13 kB)
# Using cached torchaudio-2.9.1-cp312-cp312-macosx_11_0_arm64.whl (808 kB)
# Using cached watchfiles-1.1.1-cp312-cp312-macosx_11_0_arm64.whl (391 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached docstring_parser-0.17.0-py3-none-any.whl (36 kB)
# Using cached email_validator-2.3.0-py3-none-any.whl (35 kB)
# Using cached fastapi_cli-0.0.16-py3-none-any.whl (12 kB)
# Using cached frozenlist-1.8.0-cp312-cp312-macosx_11_0_arm64.whl (50 kB)
# Using cached hf_xet-1.2.0-cp37-abi3-macosx_11_0_arm64.whl (2.7 MB)
# Using cached interegular-0.3.3-py37-none-any.whl (23 kB)
# Using cached jiter-0.12.0-cp312-cp312-macosx_11_0_arm64.whl (319 kB)
# Using cached langchain_text_splitters-1.1.0-py3-none-any.whl (34 kB)
# Using cached langgraph_checkpoint-3.0.1-py3-none-any.whl (46 kB)
# Using cached langgraph_prebuilt-1.0.5-py3-none-any.whl (35 kB)
# Using cached langgraph_sdk-0.3.0-py3-none-any.whl (66 kB)
# Using cached llvmlite-0.44.0-cp312-cp312-macosx_11_0_arm64.whl (26.2 MB)
# Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Using cached multidict-6.7.0-cp312-cp312-macosx_11_0_arm64.whl (43 kB)
# Using cached orjson-3.11.5-cp312-cp312-macosx_15_0_arm64.whl (129 kB)
# Using cached propcache-0.4.1-cp312-cp312-macosx_11_0_arm64.whl (47 kB)
# Using cached pydantic_extra_types-2.10.6-py3-none-any.whl (40 kB)
# Using cached python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Using cached python_multipart-0.0.21-py3-none-any.whl (24 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached starlette-0.50.0-py3-none-any.whl (74 kB)
# Using cached supervisor-4.3.0-py2.py3-none-any.whl (320 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached uvicorn-0.38.0-py3-none-any.whl (68 kB)
# Using cached xxhash-3.6.0-cp312-cp312-macosx_11_0_arm64.whl (30 kB)
# Using cached yarl-1.22.0-cp312-cp312-macosx_11_0_arm64.whl (94 kB)
# Using cached zstandard-0.25.0-cp312-cp312-macosx_11_0_arm64.whl (640 kB)
# Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Using cached dill-0.4.0-py3-none-any.whl (119 kB)
# Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Using cached loguru-0.7.3-py3-none-any.whl (61 kB)
# Using cached mlx_lm-0.29.1-py3-none-any.whl (324 kB)
# Using cached dnspython-2.8.0-py3-none-any.whl (331 kB)
# Using cached fastapi_cloud_cli-0.7.0-py3-none-any.whl (23 kB)
# Using cached httptools-0.7.1-cp312-cp312-macosx_11_0_arm64.whl (110 kB)
# Using cached mlx-0.30.1-cp312-cp312-macosx_26_0_arm64.whl (567 kB)
# Using cached mlx_metal-0.30.1-py3-none-macosx_26_0_arm64.whl (45.0 MB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Using cached ormsgpack-1.12.1-cp312-cp312-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (376 kB)
# Using cached pycountry-24.6.1-py3-none-any.whl (6.3 MB)
# Using cached rich_toolkit-0.17.1-py3-none-any.whl (31 kB)
# Using cached typer-0.20.0-py3-none-any.whl (47 kB)
# Using cached uvloop-0.22.1-cp312-cp312-macosx_10_13_universal2.whl (1.4 MB)
# Using cached fastar-0.8.0-cp312-cp312-macosx_11_0_arm64.whl (629 kB)
# Using cached rignore-0.7.6-cp312-cp312-macosx_11_0_arm64.whl (820 kB)
# Using cached sentry_sdk-2.48.0-py2.py3-none-any.whl (414 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Building wheels for collected packages: vllm
#   Building wheel for vllm (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for vllm (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [1951 lines of output]
#       /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/_subclasses/functional_tensor.py:279: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#         cpu = _conversion_method_template(device=torch.device("cpu"))
#       VLLM_TARGET_DEVICE automatically set to `cpu` due to macOS
#       /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/setuptools_scm/_integration/version_inference.py:51: UserWarning: version of None already set
#         warnings.warn(self.message)
#       running bdist_wheel
#       running build
#       running build_py
#       creating build/lib.macosx-11.1-arm64-cpython-312/vllm
#       copying vllm/envs.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm
#       copying vllm/tracing.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm
#       copying vllm/logits_process.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm
#       copying vllm/logprobs.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm
#       copying vllm/env_override.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm
#       copying vllm/tasks.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm
#       copying vllm/version.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm
#       copying vllm/sampling_params.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm
#       copying vllm/_custom_ops.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm
#       copying vllm/_version.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm
#       copying vllm/collect_env.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm
#       copying vllm/sequence.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm
#       copying vllm/connections.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm
#       copying vllm/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm
#       copying vllm/_ipex_ops.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm
#       copying vllm/logger.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm
#       copying vllm/beam_search.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm
#       copying vllm/pooling_params.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm
#       copying vllm/_bc_linter.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm
#       copying vllm/forward_context.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm
#       copying vllm/scripts.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm
#       copying vllm/scalar_type.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm
#       copying vllm/_aiter_ops.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm
#       copying vllm/outputs.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm
#       creating build/lib.macosx-11.1-arm64-cpython-312/vllm/v1
#       copying vllm/v1/cudagraph_dispatcher.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/v1
#       copying vllm/v1/request.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/v1
#       copying vllm/v1/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/v1
#       copying vllm/v1/utils.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/v1
#       copying vllm/v1/serial_utils.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/v1
#       copying vllm/v1/kv_cache_interface.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/v1
#       copying vllm/v1/outputs.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/v1
#       creating build/lib.macosx-11.1-arm64-cpython-312/vllm/tokenizers
#       copying vllm/tokenizers/mistral.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/tokenizers
#       copying vllm/tokenizers/registry.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/tokenizers
#       copying vllm/tokenizers/protocol.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/tokenizers
#       copying vllm/tokenizers/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/tokenizers
#       copying vllm/tokenizers/detokenizer_utils.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/tokenizers
#       copying vllm/tokenizers/hf.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/tokenizers
#       creating build/lib.macosx-11.1-arm64-cpython-312/vllm/attention
#       copying vllm/attention/selector.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/attention
#       copying vllm/attention/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/attention
#       copying vllm/attention/layer.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/attention
#       creating build/lib.macosx-11.1-arm64-cpython-312/vllm/platforms
#       copying vllm/platforms/rocm.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/platforms
#       copying vllm/platforms/cpu.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/platforms
#       copying vllm/platforms/interface.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/platforms
#       copying vllm/platforms/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/platforms
#       copying vllm/platforms/xpu.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/platforms
#       copying vllm/platforms/tpu.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/platforms
#       copying vllm/platforms/cuda.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/platforms
#       creating build/lib.macosx-11.1-arm64-cpython-312/vllm/distributed
#       copying vllm/distributed/parallel_state.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/distributed
#       copying vllm/distributed/communication_op.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/distributed
#       copying vllm/distributed/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/distributed
#       copying vllm/distributed/tpu_distributed_utils.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/distributed
#       copying vllm/distributed/utils.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/distributed
#       copying vllm/distributed/kv_events.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/distributed
#       creating build/lib.macosx-11.1-arm64-cpython-312/vllm/config
#       copying vllm/config/ec_transfer.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/config
#       copying vllm/config/speculative.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/config
#       copying vllm/config/vllm.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/config
#       copying vllm/config/device.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/config
#       copying vllm/config/multimodal.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/config
#       copying vllm/config/speech_to_text.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/config
#       copying vllm/config/cache.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/config
#       copying vllm/config/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/config
#       copying vllm/config/observability.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/config
#       copying vllm/config/model.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/config
#       copying vllm/config/compilation.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/config
#       copying vllm/config/utils.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/config
#       copying vllm/config/scheduler.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/config
#       copying vllm/config/lora.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/config
#       copying vllm/config/kv_events.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/config
#       copying vllm/config/load.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/config
#       copying vllm/config/kv_transfer.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/config
#       copying vllm/config/parallel.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/config
#       copying vllm/config/pooler.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/config
#       copying vllm/config/structured_outputs.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/config
#       creating build/lib.macosx-11.1-arm64-cpython-312/vllm/plugins
#       copying vllm/plugins/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/plugins
#       creating build/lib.macosx-11.1-arm64-cpython-312/vllm/triton_utils
#       copying vllm/triton_utils/importing.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/triton_utils
#       copying vllm/triton_utils/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/triton_utils
#       creating build/lib.macosx-11.1-arm64-cpython-312/vllm/logging_utils
#       copying vllm/logging_utils/log_time.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/logging_utils
#       copying vllm/logging_utils/formatter.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/logging_utils
#       copying vllm/logging_utils/dump_input.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/logging_utils
#       copying vllm/logging_utils/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/logging_utils
#       copying vllm/logging_utils/lazy.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/logging_utils
#       creating build/lib.macosx-11.1-arm64-cpython-312/vllm/model_executor
#       copying vllm/model_executor/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/model_executor
#       copying vllm/model_executor/utils.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/model_executor
#       copying vllm/model_executor/parameter.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/model_executor
#       copying vllm/model_executor/custom_op.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/model_executor
#       creating build/lib.macosx-11.1-arm64-cpython-312/vllm/usage
#       copying vllm/usage/usage_lib.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/usage
#       copying vllm/usage/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/usage
#       creating build/lib.macosx-11.1-arm64-cpython-312/vllm/utils
#       copying vllm/utils/func_utils.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/utils
#       copying vllm/utils/gc_utils.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/utils
#       copying vllm/utils/jsontree.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/utils
#       copying vllm/utils/math_utils.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/utils
#       copying vllm/utils/collection_utils.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/utils
#       copying vllm/utils/tensor_schema.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/utils
#       copying vllm/utils/async_utils.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/utils
#       copying vllm/utils/registry.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/utils
#       copying vllm/utils/nccl.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/utils
#       copying vllm/utils/cache.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/utils
#       copying vllm/utils/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/utils
#       copying vllm/utils/argparse_utils.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/utils
#       copying vllm/utils/system_utils.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/utils
#       copying vllm/utils/mem_utils.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/utils
#       copying vllm/utils/platform_utils.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/utils
#       copying vllm/utils/serial_utils.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/utils
#       copying vllm/utils/flashinfer.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/utils
#       copying vllm/utils/import_utils.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/utils
#       copying vllm/utils/deep_gemm.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/utils
#       copying vllm/utils/hashing.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/utils
#       copying vllm/utils/counter.py -> build/lib.macosx-11.1-arm64-cpython-312/vllm/utils
# ...
#       In file included from /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2:
#       In file included from /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include/torch/csrc/autograd/function_hook.h:3:
#       In file included from /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include/ATen/Tensor.h:3:
#       In file included from /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include/ATen/core/Tensor.h:3:
#       In file included from /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include/ATen/core/TensorBody.h:11:
#       In file included from /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include/c10/core/Device.h:3:
#       /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include/c10/core/DeviceType.h:10:10: fatal error: 'cstddef' file not found
#          10 | #include <cstddef>
#             |          ^~~~~~~~~
#       1 error generated.
#       [6/10] Building CXX object CMakeFiles/_C.dir/csrc/cpu/pos_encoding.cpp.o
#       FAILED: [code=1] CMakeFiles/_C.dir/csrc/cpu/pos_encoding.cpp.o
#       /usr/bin/c++ -DPy_LIMITED_API=3 -DTORCH_EXTENSION_NAME=_C -DUSE_C10D_GLOO -DUSE_DISTRIBUTED -DUSE_RPC -DUSE_TENSORPIPE -DVLLM_NUMA_DISABLED -D_C_EXPORTS -I/private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-install-vdweqj2l/vllm_e0c72e7c00044641b7535dbe69518714/csrc -isystem /Users/kumar/miniconda3/include/python3.12 -isystem /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include -isystem /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include/torch/csrc/api/include -O2 -g -DNDEBUG -std=gnu++17 -arch arm64 -fPIC -DVLLM_CPU_EXTENSION -march=armv8.2-a+dotprod+fp16 -MD -MT CMakeFiles/_C.dir/csrc/cpu/pos_encoding.cpp.o -MF CMakeFiles/_C.dir/csrc/cpu/pos_encoding.cpp.o.d -o CMakeFiles/_C.dir/csrc/cpu/pos_encoding.cpp.o -c /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-install-vdweqj2l/vllm_e0c72e7c00044641b7535dbe69518714/csrc/cpu/pos_encoding.cpp
#       In file included from /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-install-vdweqj2l/vllm_e0c72e7c00044641b7535dbe69518714/csrc/cpu/pos_encoding.cpp:2:
#       In file included from /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-install-vdweqj2l/vllm_e0c72e7c00044641b7535dbe69518714/csrc/cpu/cpu_types.hpp:15:
#       In file included from /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-install-vdweqj2l/vllm_e0c72e7c00044641b7535dbe69518714/csrc/cpu/cpu_types_arm.hpp:2:
#       In file included from /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include/torch/csrc/api/include/torch/all.h:7:
#       In file included from /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include/torch/csrc/api/include/torch/autograd.h:3:
#       In file included from /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include/torch/csrc/autograd/autograd.h:3:
#       In file included from /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include/torch/csrc/autograd/variable.h:6:
#       In file included from /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2:
#       In file included from /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include/torch/csrc/autograd/function_hook.h:3:
#       In file included from /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include/ATen/Tensor.h:3:
#       In file included from /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include/ATen/core/Tensor.h:3:
#       In file included from /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include/ATen/core/TensorBody.h:11:
#       In file included from /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include/c10/core/Device.h:3:
#       /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include/c10/core/DeviceType.h:10:10: fatal error: 'cstddef' file not found
#          10 | #include <cstddef>
#             |          ^~~~~~~~~
#       1 error generated.
#       [7/10] Building CXX object CMakeFiles/_C.dir/csrc/moe/dynamic_4bit_int_moe_cpu.cpp.o
#       FAILED: [code=1] CMakeFiles/_C.dir/csrc/moe/dynamic_4bit_int_moe_cpu.cpp.o
#       /usr/bin/c++ -DPy_LIMITED_API=3 -DTORCH_EXTENSION_NAME=_C -DUSE_C10D_GLOO -DUSE_DISTRIBUTED -DUSE_RPC -DUSE_TENSORPIPE -DVLLM_NUMA_DISABLED -D_C_EXPORTS -I/private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-install-vdweqj2l/vllm_e0c72e7c00044641b7535dbe69518714/csrc -isystem /Users/kumar/miniconda3/include/python3.12 -isystem /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include -isystem /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include/torch/csrc/api/include -O2 -g -DNDEBUG -std=gnu++17 -arch arm64 -fPIC -DVLLM_CPU_EXTENSION -march=armv8.2-a+dotprod+fp16 -MD -MT CMakeFiles/_C.dir/csrc/moe/dynamic_4bit_int_moe_cpu.cpp.o -MF CMakeFiles/_C.dir/csrc/moe/dynamic_4bit_int_moe_cpu.cpp.o.d -o CMakeFiles/_C.dir/csrc/moe/dynamic_4bit_int_moe_cpu.cpp.o -c /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-install-vdweqj2l/vllm_e0c72e7c00044641b7535dbe69518714/csrc/moe/dynamic_4bit_int_moe_cpu.cpp
#       In file included from /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-install-vdweqj2l/vllm_e0c72e7c00044641b7535dbe69518714/csrc/moe/dynamic_4bit_int_moe_cpu.cpp:1:
#       In file included from /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include/ATen/ATen.h:7:
#       In file included from /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include/ATen/Context.h:3:
#       In file included from /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include/ATen/BlasBackend.h:3:
#       In file included from /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include/c10/util/Exception.h:5:
#       In file included from /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include/c10/macros/Macros.h:1:
#       /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include/torch/headeronly/macros/Macros.h:3:10: fatal error: 'cassert' file not found
#           3 | #include <cassert>
#             |          ^~~~~~~~~
#       1 error generated.
#       [8/10] Building CXX object CMakeFiles/_C.dir/csrc/cpu/cpu_attn.cpp.o
#       FAILED: [code=1] CMakeFiles/_C.dir/csrc/cpu/cpu_attn.cpp.o
#       /usr/bin/c++ -DPy_LIMITED_API=3 -DTORCH_EXTENSION_NAME=_C -DUSE_C10D_GLOO -DUSE_DISTRIBUTED -DUSE_RPC -DUSE_TENSORPIPE -DVLLM_NUMA_DISABLED -D_C_EXPORTS -I/private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-install-vdweqj2l/vllm_e0c72e7c00044641b7535dbe69518714/csrc -isystem /Users/kumar/miniconda3/include/python3.12 -isystem /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include -isystem /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/torch/include/torch/csrc/api/include -O2 -g -DNDEBUG -std=gnu++17 -arch arm64 -fPIC -DVLLM_CPU_EXTENSION -march=armv8.2-a+dotprod+fp16 -MD -MT CMakeFiles/_C.dir/csrc/cpu/cpu_attn.cpp.o -MF CMakeFiles/_C.dir/csrc/cpu/cpu_attn.cpp.o.d -o CMakeFiles/_C.dir/csrc/cpu/cpu_attn.cpp.o -c /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-install-vdweqj2l/vllm_e0c72e7c00044641b7535dbe69518714/csrc/cpu/cpu_attn.cpp
#       In file included from /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-install-vdweqj2l/vllm_e0c72e7c00044641b7535dbe69518714/csrc/cpu/cpu_attn.cpp:1:
#       In file included from /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-install-vdweqj2l/vllm_e0c72e7c00044641b7535dbe69518714/csrc/cpu/cpu_attn_vec.hpp:4:
#       /private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-install-vdweqj2l/vllm_e0c72e7c00044641b7535dbe69518714/csrc/cpu/cpu_attn_impl.hpp:4:10: fatal error: 'type_traits' file not found
#           4 | #include <type_traits>
#             |          ^~~~~~~~~~~~~
#       1 error generated.
#       ninja: build stopped: subcommand failed.
#       Traceback (most recent call last):
#         File "/Users/kumar/miniconda3/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/Users/kumar/miniconda3/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/Users/kumar/miniconda3/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 251, in build_wheel
#           return _build_backend().build_wheel(wheel_directory, config_settings,
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/setuptools/build_meta.py", line 435, in build_wheel
#           return _build(['bdist_wheel', '--dist-info-dir', str(metadata_directory)])
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/setuptools/build_meta.py", line 423, in _build
#           return self._build_with_temp_dir(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/setuptools/build_meta.py", line 404, in _build_with_temp_dir
#           self.run_setup()
#         File "/private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/setuptools/build_meta.py", line 317, in run_setup
#           exec(code, locals())
#         File "<string>", line 780, in <module>
#         File "/private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/setuptools/__init__.py", line 115, in setup
#           return distutils.core.setup(**attrs)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/setuptools/_distutils/core.py", line 186, in setup
#           return run_commands(dist)
#                  ^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/setuptools/_distutils/core.py", line 202, in run_commands
#           dist.run_commands()
#         File "/private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/setuptools/_distutils/dist.py", line 1002, in run_commands
#           self.run_command(cmd)
#         File "/private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/setuptools/dist.py", line 1102, in run_command
#           super().run_command(command)
#         File "/private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/setuptools/_distutils/dist.py", line 1021, in run_command
#           cmd_obj.run()
#         File "/private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/setuptools/command/bdist_wheel.py", line 370, in run
#           self.run_command("build")
#         File "/private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/setuptools/_distutils/cmd.py", line 357, in run_command
#           self.distribution.run_command(command)
#         File "/private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/setuptools/dist.py", line 1102, in run_command
#           super().run_command(command)
#         File "/private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/setuptools/_distutils/dist.py", line 1021, in run_command
#           cmd_obj.run()
#         File "/private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/setuptools/_distutils/command/build.py", line 135, in run
#           self.run_command(cmd_name)
#         File "/private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/setuptools/_distutils/cmd.py", line 357, in run_command
#           self.distribution.run_command(command)
#         File "/private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/setuptools/dist.py", line 1102, in run_command
#           super().run_command(command)
#         File "/private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/setuptools/_distutils/dist.py", line 1021, in run_command
#           cmd_obj.run()
#         File "<string>", line 277, in run
#         File "/private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/setuptools/command/build_ext.py", line 96, in run
#           _build_ext.run(self)
#         File "/private/var/folders/b1/r67qgpbd4vg9fx69k8wngmxh0000gn/T/pip-build-env-4oddvlup/overlay/lib/python3.12/site-packages/setuptools/_distutils/command/build_ext.py", line 368, in run
#           self.build_extensions()
#         File "<string>", line 246, in build_extensions
#         File "/Users/kumar/miniconda3/lib/python3.12/subprocess.py", line 413, in check_call
#           raise CalledProcessError(retcode, cmd)
#       subprocess.CalledProcessError: Command '['cmake', '--build', '.', '-j=8', '--target=_C']' returned non-zero exit status 1.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for vllm
# Failed to build vllm
# ERROR: Could not build wheels for vllm, which is required to install pyproject.toml-based projects
# Note: you may need to restart the kernel to use updated packages.

# %%
import importlib
import config
importlib.reload(config)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 import importlib
# ----> 2 importlib.reload(config)
#
# NameError: name 'config' is not defined

# %%
# %pip install langchain-ollama
# Out:
# Collecting ollama-llm
#   Downloading ollama_llm-0.1-py3-none-any.whl.metadata (147 bytes)
# Collecting mss (from ollama-llm)
#   Downloading mss-10.1.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: Pillow in /Users/kumar/miniconda3/lib/python3.12/site-packages (from ollama-llm) (10.4.0)
# Requirement already satisfied: requests in /Users/kumar/miniconda3/lib/python3.12/site-packages (from ollama-llm) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from requests->ollama-llm) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from requests->ollama-llm) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from requests->ollama-llm) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kumar/miniconda3/lib/python3.12/site-packages (from requests->ollama-llm) (2025.8.3)
# Downloading ollama_llm-0.1-py3-none-any.whl (1.2 kB)
# Downloading mss-10.1.0-py3-none-any.whl (24 kB)
# Installing collected packages: mss, ollama-llm
# Successfully installed mss-10.1.0 ollama-llm-0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain_ollama

# %%
import numpy as np
import pandas as pd
from langchain_ollama import OllamaLLM
from langchain_core.prompts import PromptTemplate
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report
from config import Config
from evaluate import evaluate_model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 from langchain_ollama import OllamaLLM
#       4 from langchain_core.prompts import PromptTemplate
#       5 from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report
#
# ModuleNotFoundError: No module named 'langchain_ollama'

# %%
# Load your CSV
df = pd.read_csv(Config.file_path)
reviews = df["text"].tolist()

# %%
prompt = PromptTemplate(
    input_variables=["text"], # the placeholder to be replaced based on prompt template
    template=Config.zero_shot_prompt_template
)

# Load small model
llm = OllamaLLM(model=Config.model)

# Create chain using pipe operator (modern LangChain syntax)
chain = prompt | llm

# %%
# Classify each review
results = []
for r in reviews:
    result = chain.invoke({"text": r})
    # Clean the output - extract only "truthful" or "deceptive"
    label = result.strip().lower()
    # Extract first word if model adds extra text
    if " " in label:
        label = label.split()[0]
    # Remove any punctuation
    label = label.strip('.,!?;:')
    print(f"Raw output: {result} -> Cleaned: {label}")
    results.append(label)
# Out:
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive

# %%
accuracy, f1, conf_matrix = evaluate_model(df, results)

print("=" * 50)
print("ZERO-SHOT PROMPTING RESULTS")
print("=" * 50)
print("Accuracy:", accuracy)
print("\nF1 Score:", f1)
print("\nConfusion Matrix:")
print(conf_matrix)
print("=" * 50)
# Out:
# Accuracy: 0.46
#
# F1 Score: 0.3894165535956581
#
# Confusion Matrix:
# [[40 10]
#  [44  6]]

# %% [markdown]
# ## One-Shot Prompting
# Using one example to guide the model's classification

# %%
one_shot_prompt = PromptTemplate(
    input_variables=["text"],
    template = Config.one_shot_prompt_template
)
# Create one-shot chain
one_shot_chain = one_shot_prompt | llm

# %%
# Classify each review
one_shot_results = []
for r in reviews:
    result = one_shot_chain.invoke({"text": r})
    # Clean the output - extract only "truthful" or "deceptive"
    label = result.strip().lower()
    # Extract first word if model adds extra text
    if " " in label:
        label = label.split()[0]
    # Remove any punctuation
    label = label.strip('.,!?;:')
    print(f"Raw output: {result} -> Cleaned: {label}")
    one_shot_results.append(label)
# Out:
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive

# %%
accuracy_one_shot, f1_one_shot, conf_matrix_one_shot = evaluate_model(df, one_shot_results)

print("=" * 50)
print("ONE-SHOT PROMPTING RESULTS")
print("=" * 50)
print("Accuracy:", accuracy_one_shot)
print("\nF1 Score:", f1_one_shot)
print("\nConfusion Matrix:")
print(conf_matrix_one_shot)
print("=" * 50)
# Out:
# Accuracy: 0.5
#
# F1 Score: 0.3658041603247082
#
# Confusion Matrix:
# [[48  2]
#  [48  2]]

# %% [markdown]
# ## Few-Shot Prompting
# Using multiple examples to guide the model's classification

# %%
few_shot_prompt = PromptTemplate(
    input_variables=["text"],
    template=Config.few_shot_prompt_template
)

# Create few-shot chain
few_shot_chain = few_shot_prompt | llm

# %%
# Classify reviews using few-shot prompting
few_shot_results = []
for r in reviews:
    result = few_shot_chain.invoke({"text": r})
    # Clean the output
    label = result.strip().lower()
    if " " in label:
        label = label.split()[0]
    label = label.strip('.,!?;:')
    print(f"Raw output: {result} -> Cleaned: {label}")
    few_shot_results.append(label)
# Out:
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive. -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful -> Cleaned: truthful
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Truthful. -> Cleaned: truthful
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive
# Raw output: Deceptive -> Cleaned: deceptive

# %%
accuracy_few_shot, f1_few_shot, conf_matrix_few_shot = evaluate_model(df, few_shot_results)

print("=" * 50)
print("FEW-SHOT PROMPTING RESULTS")
print("=" * 50)
print("Accuracy:", accuracy_few_shot)
print("\nF1 Score:", f1_few_shot)
print("\nConfusion Matrix:")
print(conf_matrix_few_shot)
print("=" * 50)
# Out:
# Accuracy: 0.5
#
# F1 Score: 0.47916666666666674
#
# Confusion Matrix:
# [[35 15]
#  [35 15]]

# %% [markdown]
# ## Compare All Approaches
# Compare zero-shot, one-shot, and few-shot results

# %%
# Compare all approaches
comparison_df = pd.DataFrame({
    'Approach': ['Zero-Shot', 'One-Shot', 'Few-Shot'],
    'Accuracy': [accuracy, accuracy_one_shot, accuracy_few_shot],
    'F1 Score': [f1, f1_one_shot, f1_few_shot]
})

print("=" * 60)
print("COMPARISON OF ALL PROMPTING APPROACHES")
print("=" * 60)
print(comparison_df.to_string(index=False))
print("=" * 60)

# Find best approach
best_idx = comparison_df['Accuracy'].idxmax()
best_approach = comparison_df.loc[best_idx, 'Approach']
best_accuracy = comparison_df.loc[best_idx, 'Accuracy']
print(f"\nBest Approach: {best_approach} (Accuracy: {best_accuracy:.4f})")
# Out:
# ============================================================
# COMPARISON OF ALL PROMPTING APPROACHES
# ============================================================
#  Approach  Accuracy  F1 Score
# Zero-Shot      0.46  0.389417
#  One-Shot      0.50  0.365804
#  Few-Shot      0.50  0.479167
# ============================================================
#
# Best Approach: One-Shot (Accuracy: 0.5000)
